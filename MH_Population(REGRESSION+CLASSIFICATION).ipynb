# %% [markdown]
# **Import all Required Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.multioutput import MultiOutputRegressor, MultiOutputClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# **Load RAW Data**

# %%
df_raw = pd.read_csv("/content/MH Population.csv")
df_raw.columns = df_raw.columns.str.strip()
print("Raw Shape:", df_raw.shape)
# Out:
# Raw Shape: (35, 28)

# %% [markdown]
# ------
# # **Regression Prediction**

# %%
reg_targets = ["Population_2021", "Population_2031"]
df_model_reg = df_raw.copy()

# %% [markdown]
# **Encode categorical columns for Regression**

# %%
cat_cols_reg = df_model_reg.select_dtypes(include="object").columns
cat_cols_reg = [col for col in cat_cols_reg if col not in reg_targets]
le_dict_reg = {}
for col in cat_cols_reg:
    le = LabelEncoder()
    df_model_reg[col] = le.fit_transform(df_model_reg[col])
    le_dict_reg[col] = le

# %% [markdown]
# **Split Features and Target**

# %%
X_reg = df_model_reg.drop(columns=reg_targets + ["District"])
y_reg = df_model_reg[reg_targets]

# %% [markdown]
# **Train-test split**

# %%
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
                X_reg, y_reg, test_size=0.2, random_state=42)

# %% [markdown]
# **Multi-output Regression**

# %%
reg_model = MultiOutputRegressor(
    RandomForestRegressor(n_estimators=300, random_state=42, n_jobs=-1))

reg_model.fit(X_train_reg, y_train_reg)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(n_estimators=300,
#                                                      n_jobs=-1,
#                                                      random_state=42))

# %% [markdown]
# **Metrics Evaluation**

# %%
r2_scores = reg_model.score(X_test_reg, y_test_reg)
print("Regression Test R²:", round(r2_scores, 2))
# Out:
# Regression Test R²: 0.94

# %% [markdown]
# **Predict all districts**

# %%
all_reg_predictions = reg_model.predict(X_reg)
df_reg_predictions = df_raw[["District"]].copy()
df_reg_predictions["Predicted_Population_2021"] = all_reg_predictions[:, 0].astype(int)
df_reg_predictions["Predicted_Population_2031"] = all_reg_predictions[:, 1].astype(int)

# %% [markdown]
# -------
# # **CLASSIFICATION PREDICTION**

# %%
class_targets = [
    "Growth Category",
    "Urban Pressure Category",
    "Migration Zone",
    "Negative_Growth_Flag",
    "Pandemic Impact"]

# %%
df_model_clf = df_raw.copy()

# %%
df_model_clf.columns = df_model_clf.columns.str.strip()

# %% [markdown]
# **Ensure all class Targets Exist**

# %%
missing_cols = [col for col in class_targets if col not in df_model_clf.columns]
if missing_cols:
    raise ValueError(f"Missing classification columns: {missing_cols}")

# %%
feature_cols_clf = [col for col in df_model_clf.columns if col not in class_targets + reg_targets + ["District"]]

# %% [markdown]
# **Encode categorical features**

# %%
categorical_features = df_model_clf[feature_cols_clf].select_dtypes(include="object").columns
feature_encoders = {}
for col in categorical_features:
    le = LabelEncoder()
    df_model_clf[col] = le.fit_transform(df_model_clf[col])
    feature_encoders[col] = le

# %% [markdown]
# **Encode class targets**

# %%
target_encoders = {}
for col in class_targets:
    le = LabelEncoder()
    df_model_clf[col] = le.fit_transform(df_model_clf[col])
    target_encoders[col] = le

# %% [markdown]
# **Split features and targets**

# %%
X_clf = df_model_clf[feature_cols_clf]
y_clf = df_model_clf[class_targets]

# %% [markdown]
# **Train-test split**

# %%
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(
    X_clf, y_clf, test_size=0.2, random_state=42)

# %% [markdown]
# **Multi-output classifier**

# %%
clf_model = MultiOutputClassifier(
    RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1))

clf_model.fit(X_train_clf, y_train_clf)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(n_estimators=200,
#                                                        n_jobs=-1,
#                                                        random_state=42))

# %%
from sklearn.metrics import accuracy_score

for i, col in enumerate(class_targets):
    acc = accuracy_score(y_clf[col], all_clf_predictions[:, i])
    print(f"{col} Accuracy: {acc:.2f}")
# Out:
# Growth Category Accuracy: 0.97
# Urban Pressure Category Accuracy: 0.97
# Migration Zone Accuracy: 0.94
# Negative_Growth_Flag Accuracy: 1.00
# Pandemic Impact Accuracy: 1.00

# %% [markdown]
# **Predict all districts**

# %%
all_clf_predictions = clf_model.predict(X_clf)

# %% [markdown]
# **Decode predictions**

# %%
df_clf_predictions = df_raw[["District"]].copy()
for i, col in enumerate(class_targets):
    df_clf_predictions[col] = target_encoders[col].inverse_transform(all_clf_predictions[:, i])

# %% [markdown]
# **MERGE REGRESSION + CLASSIFICATION**

# %%
df_final = df_reg_predictions.merge(df_clf_predictions, on="District")

# %% [markdown]
# **EXPORT FINAL CSV**

# %%
df_final
# Out:
#            District  Predicted_Population_2021  Predicted_Population_2031  \
# 0             Thane                   11564305                   13735062
# 1              Pune                   10009266                   11751463
# 2   Mumbai Suburban                    9276498                   10067167
# 3            Nashik                    6217641                    6969623
# 4            Nagpur                    4874406                    5241265
# 5        Ahmadnagar                    4775993                    5142766
# 6           Solapur                    4571633                    4886726
# 7           Jalgaon                    4597111                    4990674
# 8          Kolhapur                    4196191                    4446990
# 9        Aurangabad                    5197938                    5620613
# 10           Nanded                    3637791                    4087922
# 11      Mumbai City                    4274384                    4442275
# 12           Satara                    3063106                    3180229
# 13         Amravati                    2937569                    3044257
# 14           Sangli                    2955171                    3128714
# 15         Yavatmal                    2853186                    3048270
# 16          Raigarh                    2939700                    3270432
# 17          Buldana                    2832655                    3102143
# 18             Beed                    2975992                    3186045
# 19            Latur                    2799950                    3032366
# 20       Chandrapur                    2256899                    2436125
# 21            Dhule                    2186451                    2475969
# 22            Jalna                    2158966                    2484414
# 23         Parbhani                    2094670                    2408254
# 24            Akola                    2030718                    2400109
# 25        Osmanabad                    1710947                    1821932
# 26        Nandurbar                    2206135                    2278732
# 27        Ratnagiri                    1586348                    1573716
# 28          Gondiya                    1333373                    1424213
# 29           Wardha                    1252824                    1395343
# 30         Bhandara                    1315490                    1372621
# 31           Washim                    1349382                    1476521
# 32          Hingoli                    1370282                    1540175
# 33       Gadchiroli                    1247540                    1299504
# 34       Sindhudurg                    1020777                    1029795
#
#     Growth Category Urban Pressure Category         Migration Zone  \
# 0      Rapid Growth       Very High Density      High In-Migration
# 1      Rapid Growth            High Density      High In-Migration
# 2        Low Growth         Extreme Density   Extreme In-Migration
# 3   Moderate Growth        Moderate Density  Moderate In-Migration
# 4   Moderate Growth        Moderate Density  Moderate In-Migration
# 5   Moderate Growth        Moderate Density  Moderate In-Migration
# 6   Moderate Growth        Moderate Density  Moderate In-Migration
# 7   Moderate Growth        Moderate Density  Moderate In-Migration
# 8   Moderate Growth            High Density  Moderate In-Migration
# 9      Rapid Growth        Moderate Density      High In-Migration
# 10  Moderate Growth        Moderate Density  Moderate In-Migration
# 11        Declining         Extreme Density     Out-Migration Zone
# 12       Low Growth        Moderate Density       Low In-Migration
# 13  Moderate Growth        Moderate Density  Moderate In-Migration
# 14  Moderate Growth        Moderate Density  Moderate In-Migration
# 15  Moderate Growth             Low Density  Moderate In-Migration
# 16  Moderate Growth        Moderate Density  Moderate In-Migration
# 17  Moderate Growth        Moderate Density  Moderate In-Migration
# 18  Moderate Growth             Low Density  Moderate In-Migration
# 19  Moderate Growth        Moderate Density  Moderate In-Migration
# 20       Low Growth             Low Density       Low In-Migration
# 21  Moderate Growth        Moderate Density  Moderate In-Migration
# 22  Moderate Growth        Moderate Density  Moderate In-Migration
# 23  Moderate Growth        Moderate Density  Moderate In-Migration
# 24  Moderate Growth        Moderate Density  Moderate In-Migration
# 25  Moderate Growth             Low Density       Low In-Migration
# 26  Moderate Growth        Moderate Density  Moderate In-Migration
# 27        Declining             Low Density     Out-Migration Zone
# 28  Moderate Growth        Moderate Density       Low In-Migration
# 29       Low Growth             Low Density       Low In-Migration
# 30       Low Growth        Moderate Density       Low In-Migration
# 31  Moderate Growth             Low Density  Moderate In-Migration
# 32  Moderate Growth             Low Density  Moderate In-Migration
# 33  Moderate Growth             Low Density       Low In-Migration
# 34        Declining             Low Density     Out-Migration Zone
#
#     Negative_Growth_Flag Pandemic Impact
# 0                      0     Mild Impact
# 1                      0     Mild Impact
# 2                      0   Severe Impact
# 3                      0     Mild Impact
# 4                      0     Mild Impact
# 5                      0     Mild Impact
# 6                      0     Mild Impact
# 7                      0     Mild Impact
# 8                      0     Mild Impact
# 9                      0     Mild Impact
# 10                     0     Mild Impact
# 11                     1   Severe Impact
# 12                     0     Mild Impact
# 13                     0     Mild Impact
# 14                     0     Mild Impact
# 15                     0     Mild Impact
# 16                     0     Mild Impact
# 17                     0     Mild Impact
# 18                     0     Mild Impact
# 19                     0     Mild Impact
# 20                     0     Mild Impact
# 21                     0     Mild Impact
# 22                     0     Mild Impact
# 23                     0     Mild Impact
# 24                     0     Mild Impact
# 25                     0     Mild Impact
# 26                     0     Mild Impact
# 27                     1     Mild Impact
# 28                     0     Mild Impact
# 29                     0     Mild Impact
# 30                     0     Mild Impact
# 31                     0     Mild Impact
# 32                     0     Mild Impact
# 33                     0     Mild Impact
# 34                     1     Mild Impact

# %%
df_final.to_csv("MH_Population_Full_Predictions.csv", index=False)
